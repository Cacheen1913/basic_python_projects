# %%
#RESUME USING API

from flask import Flask
app = Flask(__name__)

@app.route("/")
def home():
    return """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8" />
<meta name="viewport" content="width=device-width, initial-scale=1.0" />
<title>Resume</title>
<style>
    body {
        font-family: Arial, sans-serif;
        background: #f4f4f4;
        margin: 0;
        padding: 0;
    }
    .container {
        max-width: 800px;
        background: #fff;
        margin: 40px auto;
        padding: 30px;
        box-shadow: 0 0 10px rgba(0,0,0,0.1);
        border-radius: 8px;
    }
    h1, h2 {
        color: #333;
    }
    h1 { font-size: 32px; margin-bottom: 5px; }
    .section {
        margin-bottom: 25px;
    }
    .section-title {
        font-size: 22px;
        font-weight: bold;
        margin-bottom: 10px;
        color: #222;
    }
    ul {
        margin: 0;
        padding-left: 20px;
    }
</style>
</head>
<body>
<div class="container">

    <h1>Sachin Sah</h1>
    <p><strong>Email:</strong> sachinsah590@gmail.com<br>
       <strong>Phone:</strong> 8597100716<br>
       <strong>Location:</strong> Jaipur, India
    </p>

    <div class="section">
        <div class="section-title">Objective</div>
        <p>A motivated and dedicated aspiring software developer with strong knowledge of C, Java, Python, and basic web development (HTML & CSS). Looking for opportunities to apply skills, build impactful projects, and grow in a professional environment.</p>
    </div>

    <div class="section">
        <div class="section-title">Skills</div>
        <ul>
            <li><strong>Programming Languages:</strong> C, Java, Python</li>
            <li><strong>Web Technologies:</strong> HTML, CSS</li>
            <li><strong>Tools & Technologies:</strong> Git, GitHub, VS Code, Flask (beginner), Streamlit (beginner)</li>
            <li><strong>Core Strengths:</strong> Problem-solving, debugging, logical thinking, fast learner</li>
        </ul>
    </div>

    <div class="section">
        <div class="section-title">Projects</div>
        <ul>
            <li><strong>XO Game (Python – Pygame):</strong> Developed an interactive XO game with turn logic, grid mapping, and win detection.</li>
            <li><strong>Email Automation Script (Python – SMTP):</strong> Automated sending emails using secure Gmail app authentication.</li>
            <li><strong>SMS Automation (Twilio API):</strong> Integrated Twilio API to send automated SMS with verified sender systems.</li>
            <li><strong>Resume Web App (Flask):</strong> Built a Flask app to render a responsive resume webpage using HTML & CSS.</li>
        </ul>
    </div>

    <div class="section">
        <div class="section-title">Education</div>
        <p>Bachelor of Technology (BTECH)<br>
        Jaipur — 2024–Present</p>
    </div>

    <div class="section">
        <div class="section-title">Certificates</div>
        <ul>
            <li>Python Programming Basics</li>
            <li>Java Fundamentals</li>
            <li>HTML & CSS Basics</li>
        </ul>
    </div>

    <div class="section">
        <div class="section-title">Languages</div>
        <ul>
            <li>English</li>
            <li>Hindi</li>
        </ul>
    </div>

    <div class="section">
        <div class="section-title">Declaration</div>
        <p>I hereby declare that all the information provided above is true to the best of my knowledge.</p>
        <p><strong>Date:</strong> ___________<br><strong>Signature:</strong> ___________</p>
    </div>

</div>
</body>
</html>
    """

@app.route("/about")
def abouta():
    return """
    <h1>I am home page</h1>
    <h2>This is demo of about page</h2>
    """
    
if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Nov/2025 03:22:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Nov/2025 03:22:44] "GET /favicon.ico HTTP/1.1" 404 -
