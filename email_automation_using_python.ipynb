# %%
#EMAIL AUTOMATION

import smtplib
import ssl
from email.message import EmailMessage

EMAIL = "**************"     #enter sender email here
APP_PASSWORD = "***********" #enter app password here
RECEIVER = "************"    #enter receiver email here

msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "Test Email from Python"

msg.set_content("Hey, I came here also. I am Python!")
context = ssl.create_default_context()

with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
    server.login(EMAIL, APP_PASSWORD)
    server.send_message(msg)
    print("Your Email sent successfully!")
# Out:
# Your Email sent successfully!
