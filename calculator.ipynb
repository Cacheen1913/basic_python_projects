# %%
# Simple Calculator

print("Welcome user")

while True:
    print("Press 0 for exit!")
    user = int(input("Here are the list of operations which you can perfrom\n"
     "1. Addition\n"
     "2. Subtraction\n"
     "3. Multiplication\n"
     "4. Division\n"))

    if user == 1:
        num1 = int(input("Enter the first number"))
        num2 = int(input("Enter the second number"))
        print(f"Addition of {num1} and {num2} is:  {num1+num2}")
    elif user == 2:
        num1 = int(input("Enter the first number"))
        num2 = int(input("Enter the second number"))
        print(f"Subtraction of {num1} and {num2} is: {num1-num2}")
    elif user == 3:
        num1 = int(input("Enter the first number"))
        num2 = int(input("Enter the second number"))
        print(f"Multiplication of {num1} and {num2} is:  {num1*num2}")
    elif user == 4:
        num1 = int(input("Enter the first number"))
        num2 = int(input("Enter the second number"))
        print(f"Division of {num1} and {num2} is:  {num1/num2}")
    elif user == 0:
        print("Bye Bye!")
        break
    else:
        print("Invalid input! Try again")
# Out:
# Welcome user
# Press 0 for exit!
# Here are the list of operations which you can perfrom
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
#  1
# Enter the first number 10
# Enter the second number 20
# Addition of 10 and 20 is:  30
# Press 0 for exit!
# Here are the list of operations which you can perfrom
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
#  3
# Enter the first number 4
# Enter the second number 7
# Multiplication of 4 and 7 is:  28
# Press 0 for exit!
# Here are the list of operations which you can perfrom
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
#  0
# Bye Bye!
