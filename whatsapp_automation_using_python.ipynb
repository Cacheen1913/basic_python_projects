# %%
#WHATSAPP MESSAGE AUTOMATION

import pywhatkit

pywhatkit.sendwhatmsg_instantly("***********", "Hello I am python")     #enter receiver mobile number here
print("Message sent successfully.....")
# pywhatkit.sendwhatmsg("+918597100716", "I am again Python", 23, 59)
# Out:
# Message sent successfully.....
